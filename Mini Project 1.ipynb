# %% [markdown]
# ## MINI-PROJECT 1

# %% [markdown]
# ## Read the data

# %%
import pandas as pd
df=pd.read_excel(r"C:\Users\hp\PYTHON\weather_data_XL.xlsx")
df
# Out:
#         Date        City  Temperature_C  Humidity_% Condition
# 0 2025-01-01    Hyderbad             28          60     Sunny
# 1 2025-01-02    Hyderbad             29          62     Sunny
# 2 2025-01-03    Hyderbad             30          58    Cloudy
# 3 2025-01-04    Hyderbad             31          55    Cloudy
# 4 2025-01-05    Banglore             32          57     Rainy
# 5 2025-01-06    Banglore             33          59     Rainy
# 6 2025-01-07    Banglore             34          61     Sunny
# 7 2025-01-08    Banglore             32          63    Cloudy
# 8 2025-01-09  Vijayawada             31          64     Rainy
# 9 2025-01-10  Vijayawada             29          62     Sunny

# %% [markdown]
# ## Exploring data

# %%
df.head()
# Out:
#         Date      City  Temperature_C  Humidity_% Condition
# 0 2025-01-01  Hyderbad             28          60     Sunny
# 1 2025-01-02  Hyderbad             29          62     Sunny
# 2 2025-01-03  Hyderbad             30          58    Cloudy
# 3 2025-01-04  Hyderbad             31          55    Cloudy
# 4 2025-01-05  Banglore             32          57     Rainy

# %%
df.head(10)
# Out:
#         Date        City  Temperature_C  Humidity_% Condition
# 0 2025-01-01    Hyderbad             28          60     Sunny
# 1 2025-01-02    Hyderbad             29          62     Sunny
# 2 2025-01-03    Hyderbad             30          58    Cloudy
# 3 2025-01-04    Hyderbad             31          55    Cloudy
# 4 2025-01-05    Banglore             32          57     Rainy
# 5 2025-01-06    Banglore             33          59     Rainy
# 6 2025-01-07    Banglore             34          61     Sunny
# 7 2025-01-08    Banglore             32          63    Cloudy
# 8 2025-01-09  Vijayawada             31          64     Rainy
# 9 2025-01-10  Vijayawada             29          62     Sunny

# %%
df.tail()
# Out:
#         Date        City  Temperature_C  Humidity_% Condition
# 5 2025-01-06    Banglore             33          59     Rainy
# 6 2025-01-07    Banglore             34          61     Sunny
# 7 2025-01-08    Banglore             32          63    Cloudy
# 8 2025-01-09  Vijayawada             31          64     Rainy
# 9 2025-01-10  Vijayawada             29          62     Sunny

# %%
df.tail(7)
# Out:
#         Date        City  Temperature_C  Humidity_% Condition
# 3 2025-01-04    Hyderbad             31          55    Cloudy
# 4 2025-01-05    Banglore             32          57     Rainy
# 5 2025-01-06    Banglore             33          59     Rainy
# 6 2025-01-07    Banglore             34          61     Sunny
# 7 2025-01-08    Banglore             32          63    Cloudy
# 8 2025-01-09  Vijayawada             31          64     Rainy
# 9 2025-01-10  Vijayawada             29          62     Sunny

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           10 non-null     datetime64[ns]
#  1   City           10 non-null     object
#  2   Temperature_C  10 non-null     int64
#  3   Humidity_%     10 non-null     int64
#  4   Condition      10 non-null     object
# dtypes: datetime64[ns](1), int64(2), object(2)
# memory usage: 532.0+ bytes

# %%
df.columns
# Out:
# Index(['Date', 'City', 'Temperature_C', 'Humidity_%', 'Condition'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
df.dtypes
# Out:
# Date             datetime64[ns]
# City                     object
# Temperature_C             int64
# Humidity_%                int64
# Condition                object
# dtype: object

# %%
df.Date
# Out:
# 0   2025-01-01
# 1   2025-01-02
# 2   2025-01-03
# 3   2025-01-04
# 4   2025-01-05
# 5   2025-01-06
# 6   2025-01-07
# 7   2025-01-08
# 8   2025-01-09
# 9   2025-01-10
# Name: Date, dtype: datetime64[ns]

# %%
df.City
# Out:
# 0      Hyderbad
# 1      Hyderbad
# 2      Hyderbad
# 3      Hyderbad
# 4      Banglore
# 5      Banglore
# 6      Banglore
# 7      Banglore
# 8    Vijayawada
# 9    Vijayawada
# Name: City, dtype: object

# %%
df.shape
# Out:
# (10, 5)

# %%
df[2:5]
# Out:
#         Date      City  Temperature_C  Humidity_% Condition
# 2 2025-01-03  Hyderbad             30          58    Cloudy
# 3 2025-01-04  Hyderbad             31          55    Cloudy
# 4 2025-01-05  Banglore             32          57     Rainy

# %%
df[['Date','Condition']]
# Out:
#         Date Condition
# 0 2025-01-01     Sunny
# 1 2025-01-02     Sunny
# 2 2025-01-03    Cloudy
# 3 2025-01-04    Cloudy
# 4 2025-01-05     Rainy
# 5 2025-01-06     Rainy
# 6 2025-01-07     Sunny
# 7 2025-01-08    Cloudy
# 8 2025-01-09     Rainy
# 9 2025-01-10     Sunny

# %%
Data={
    'Name':['Aruna','Tulasi','Moina','Sravanthi','Manasa','Devi','Sriya','Roshini','Jaya','Anitha','Hannah'],
    'Age':[21,20,20,19,19,19,20,20,21,20,19],
    'Branch':['BCA','BCA','BCA','BSC','BSC','BBA','BBA','BCA','BBA','BSC','BCA'],
    'Marks':[100,99,98,95,93,89,94,79,88,90,91],
    'Location':['kkd','kkd','kkd','kkd','hyd','hyd','hyd','vjy','vjy','rjy','rjy']
}
df=pd.DataFrame(Data)
df
# Out:
#          Name  Age Branch  Marks Location
# 0       Aruna   21    BCA    100      kkd
# 1      Tulasi   20    BCA     99      kkd
# 2       Moina   20    BCA     98      kkd
# 3   Sravanthi   19    BSC     95      kkd
# 4      Manasa   19    BSC     93      hyd
# 5        Devi   19    BBA     89      hyd
# 6       Sriya   20    BBA     94      hyd
# 7     Roshini   20    BCA     79      vjy
# 8        Jaya   21    BBA     88      vjy
# 9      Anitha   20    BSC     90      rjy
# 10     Hannah   19    BCA     91      rjy

# %%
df.head()
# Out:
#         Name  Age Branch  Marks Location
# 0      Aruna   21    BCA    100      kkd
# 1     Tulasi   20    BCA     99      kkd
# 2      Moina   20    BCA     98      kkd
# 3  Sravanthi   19    BSC     95      kkd
# 4     Manasa   19    BSC     93      hyd

# %%
df.head(8)
# Out:
#         Name  Age Branch  Marks Location
# 0      Aruna   21    BCA    100      kkd
# 1     Tulasi   20    BCA     99      kkd
# 2      Moina   20    BCA     98      kkd
# 3  Sravanthi   19    BSC     95      kkd
# 4     Manasa   19    BSC     93      hyd
# 5       Devi   19    BBA     89      hyd
# 6      Sriya   20    BBA     94      hyd
# 7    Roshini   20    BCA     79      vjy

# %%
df.tail()
# Out:
#        Name  Age Branch  Marks Location
# 6     Sriya   20    BBA     94      hyd
# 7   Roshini   20    BCA     79      vjy
# 8      Jaya   21    BBA     88      vjy
# 9    Anitha   20    BSC     90      rjy
# 10   Hannah   19    BCA     91      rjy

# %%
df.tail(9)
# Out:
#          Name  Age Branch  Marks Location
# 2       Moina   20    BCA     98      kkd
# 3   Sravanthi   19    BSC     95      kkd
# 4      Manasa   19    BSC     93      hyd
# 5        Devi   19    BBA     89      hyd
# 6       Sriya   20    BBA     94      hyd
# 7     Roshini   20    BCA     79      vjy
# 8        Jaya   21    BBA     88      vjy
# 9      Anitha   20    BSC     90      rjy
# 10     Hannah   19    BCA     91      rjy

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      11 non-null     object
#  1   Age       11 non-null     int64
#  2   Branch    11 non-null     object
#  3   Marks     11 non-null     int64
#  4   Location  11 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 572.0+ bytes

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Branch', 'Marks', 'Location'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=11, step=1)

# %%
df.dtypes
# Out:
# Name        object
# Age          int64
# Branch      object
# Marks        int64
# Location    object
# dtype: object

# %%
df.Name
# Out:
# 0         Aruna
# 1        Tulasi
# 2         Moina
# 3     Sravanthi
# 4        Manasa
# 5          Devi
# 6         Sriya
# 7       Roshini
# 8          Jaya
# 9        Anitha
# 10       Hannah
# Name: Name, dtype: object

# %%
df.Marks
# Out:
# 0     100
# 1      99
# 2      98
# 3      95
# 4      93
# 5      89
# 6      94
# 7      79
# 8      88
# 9      90
# 10     91
# Name: Marks, dtype: int64

# %%
df.shape
# Out:
# (11, 5)

# %%
df[2:5]
# Out:
#         Name  Age Branch  Marks Location
# 2      Moina   20    BCA     98      kkd
# 3  Sravanthi   19    BSC     95      kkd
# 4     Manasa   19    BSC     93      hyd

# %%
df[['Name','Marks']]
# Out:
#          Name  Marks
# 0       Aruna    100
# 1      Tulasi     99
# 2       Moina     98
# 3   Sravanthi     95
# 4      Manasa     93
# 5        Devi     89
# 6       Sriya     94
# 7     Roshini     79
# 8        Jaya     88
# 9      Anitha     90
# 10     Hannah     91

# %%
df[['Name','Marks','Branch']]
# Out:
#          Name  Marks Branch
# 0       Aruna    100    BCA
# 1      Tulasi     99    BCA
# 2       Moina     98    BCA
# 3   Sravanthi     95    BSC
# 4      Manasa     93    BSC
# 5        Devi     89    BBA
# 6       Sriya     94    BBA
# 7     Roshini     79    BCA
# 8        Jaya     88    BBA
# 9      Anitha     90    BSC
# 10     Hannah     91    BCA
